# %% [markdown]
# ##Climate Trace Dataset Investigation
#
# Source: https://huggingface.co/datasets/tjhunter/climate-trace/tree/main/v3-2024-ct5

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %%
# Dependencies

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, when, max, min, count, countDistinct, lit
from pyspark.sql.types import StringType
from pyspark.sql.functions import countDistinct
from IPython.display import display

# Create a SparkSession
spark = SparkSession.builder.appName("ClimateTrace").getOrCreate()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Parquet Files
parquet_files = {
    "2021_ch4.parquet" : 2021,
    "2021_co2.parquet" : 2021,
    "2021_n2o.parquet" : 2021,
    "2021_co2e_100yr.parquet" : 2021,
    "2022_ch4.parquet" : 2022,
    "2022_co2.parquet" : 2022,
    "2022_n2o.parquet" : 2022,
    "2022_co2e_100yr.parquet" : 2022,
    "2023_ch4.parquet" : 2023,
    "2023_co2.parquet" : 2023,
    "2023_n2o.parquet" : 2023,
    "2023_co2e_100yr.parquet" : 2023,
    "2024_ch4.parquet" : 2024,
    "2024_co2.parquet" : 2024,
    "2024_n2o.parquet" : 2024,
    "2024_co2e_100yr.parquet" : 2024
}
print("Parquet Files in the directory:\n")
for each in parquet_files:
    print(each)

target_parquet = input("Enter the target parquet file name to upload: ").strip()
df = None

if target_parquet in parquet_files:
    parquet_file = f"/content/drive/MyDrive/School Projects/Climate Trace Analysis/raw_data/{parquet_files[target_parquet]}/{target_parquet}"
    df = spark.read.parquet(parquet_file)
    print("Parquet file loaded successfully.")
else:
    print("Invalid input. Please enter a valid parquet file name.")
# Out:
# Parquet Files in the directory:
#
# 2021_ch4.parquet
# 2021_co2.parquet
# 2021_n2o.parquet
# 2021_co2e_100yr.parquet
# 2022_ch4.parquet
# 2022_co2.parquet
# 2022_n2o.parquet
# 2022_co2e_100yr.parquet
# 2023_ch4.parquet
# 2023_co2.parquet
# 2023_n2o.parquet
# 2023_co2e_100yr.parquet
# 2024_ch4.parquet
# 2024_co2.parquet
# 2024_n2o.parquet
# 2024_co2e_100yr.parquet
# Enter the target parquet file name to upload: 2021_ch4.parquet
# Parquet file loaded successfully.

# %%
# Schema Exploration
print("Schema Exploration")
df.printSchema()
# Out:
# Schema Exploration
# root
#  |-- source_id: decimal(20,0) (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- sector: string (nullable = true)
#  |-- subsector: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- source_name: string (nullable = true)
#  |-- source_type: string (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- other1: string (nullable = true)
#  |-- other2: string (nullable = true)
#  |-- other3: string (nullable = true)
#  |-- other4: string (nullable = true)
#  |-- other5: string (nullable = true)
#  |-- other6: string (nullable = true)
#  |-- other7: string (nullable = true)
#  |-- other8: string (nullable = true)
#  |-- other9: string (nullable = true)
#  |-- other10: string (nullable = true)
#  |-- other11: string (nullable = true)
#  |-- other12: string (nullable = true)
#  |-- other1_def: string (nullable = true)
#  |-- other2_def: string (nullable = true)
#  |-- other3_def: string (nullable = true)
#  |-- other4_def: string (nullable = true)
#  |-- other5_def: string (nullable = true)
#  |-- other6_def: string (nullable = true)
#  |-- other7_def: string (nullable = true)
#  |-- other8_def: string (nullable = true)
#  |-- other9_def: string (nullable = true)
#  |-- other10_def: string (nullable = true)
#  |-- other11_def: string (nullable = true)
#  |-- other12_def: string (nullable = true)
#  |-- geometry_ref: string (nullable = true)
#  |-- conf_source_type: string (nullable = true)
#  |-- conf_capacity: string (nullable = true)
#  |-- conf_capacity_factor: string (nullable = true)
#  |-- conf_activity: string (nullable = true)
#  |-- conf_emissions_factor: string (nullable = true)
#  |-- conf_emissions_quantity: string (nullable = true)
#  |-- year: long (nullable = true)

# %% [markdown]
# # source_id
#
# **Description:** Unique identifier for data source.
#
# - **Data Type:** decimal(20,0)
# - **Status:** READY
# - **Null Count:** 0
# - **Total Records:** 15,184,500
# - **Min Value:** 110
# - **Max Value:** 38,339,430
# - **Sample Head:** 11082620 (x4), 11082721
# - **Sample Tail:** 38339430 (x5)
# - **Top Value Count:** All top IDs appear 12 times
# - **Observation:** No missing data. High repetition. Can optimize storage by converting from `uint64` to `int64`.

# %%
# Source ID Exploration

column_title = "Source ID"
column_name = "source_id"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Source ID Data Type
# DecimalType(20,0)
#
# Source ID Head Values:
# +---------+
# |source_id|
# +---------+
# | 11082620|
# | 11082620|
# | 11082620|
# | 11082620|
# | 11082721|
# +---------+
# only showing top 5 rows
#
# Source ID Tail Values:
# +---------+
# |source_id|
# +---------+
# | 38339430|
# | 38339430|
# | 38339430|
# | 38339430|
# | 38339430|
# +---------+
# only showing top 5 rows
#
# +---------+---------+
# |Max Value|Min Value|
# +---------+---------+
# | 38339430|      110|
# +---------+---------+
#
# Source ID Count:
# 15184500
#
# Source ID Value Counts:
# +---------+-----+
# |source_id|count|
# +---------+-----+
# | 11097298|   12|
# | 37215827|   12|
# | 11127731|   12|
# | 11131222|   12|
# | 11115712|   12|
# | 11128080|   12|
# | 10721281|   12|
# | 10778725|   12|
# | 10843369|   12|
# | 10824069|   12|
# | 10859706|   12|
# | 11248289|   12|
# | 11278174|   12|
# | 11293635|   12|
# | 11293472|   12|
# | 11295944|   12|
# | 37177796|   12|
# | 10932135|   12|
# | 10920486|   12|
# | 10723610|   12|
# +---------+-----+
# only showing top 20 rows
#
# Source ID Null Count:
# 0

# %% [markdown]
# ## <span style="color: white; font-weight: bold; text-decoration: underline;">iso3_country</span>
# The ISO 3 country code is a three-letter code that is used to identify countries.
#
# Data Type: `string`
#
# **Status: <span style="color: red;">NOT READY</span>**
#
# Problems:
# 1. there is an invalid country code in some dataset parquet
#
#     There are 2 countries that are not in the ISO 3166-1 alpha-3 standard:
#     - UNK
#     - ZNC
#
#     UNK is unknown and ZNC is a country code in Africa for unlisted countries.
#     Replace ZNC with UNK.

# %%
column_title = "iso3 Country Code"
column_name = "iso3_country"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# iso3 Country Code Data Type
# StringType()
#
# iso3 Country Code Head Values:
# +------------+
# |iso3_country|
# +------------+
# |         KGZ|
# |         KGZ|
# |         KGZ|
# |         KGZ|
# |         KGZ|
# +------------+
# only showing top 5 rows
#
# iso3 Country Code Tail Values:
# +------------+
# |iso3_country|
# +------------+
# |         ZWE|
# |         ZWE|
# |         ZWE|
# |         ZWE|
# |         ZWE|
# +------------+
# only showing top 5 rows
#
# iso3 Country Code Distinct Values:
# +------------+
# |iso3_country|
# +------------+
# |         NIU|
# |         CCK|
# |         HTI|
# |         PSE|
# |         LVA|
# |         BRB|
# |         POL|
# |         ZMB|
# |         JAM|
# |         BRA|
# |         SPM|
# |         ARM|
# |         MOZ|
# |         JOR|
# |         CUB|
# |         FRA|
# |         SOM|
# |         ABW|
# |         TCA|
# |         COD|
# +------------+
# only showing top 20 rows
#
# iso3 Country Code Count:
# 15184500
#
# iso3 Country Code Value Counts:
# +------------+-------+
# |iso3_country|  count|
# +------------+-------+
# |         NIU|    192|
# |         CCK|    156|
# |         HTI|  13872|
# |         PSE|   5004|
# |         LVA|   8436|
# |         BRB|   2160|
# |         POL| 112140|
# |         ZMB|  33480|
# |         JAM|   4452|
# |         BRA|1288560|
# |         SPM|    528|
# |         ARM|   3168|
# |         MOZ|  35592|
# |         JOR|  15432|
# |         CUB|  43056|
# |         FRA| 385368|
# |         SOM|  20040|
# |         ABW|    252|
# |         TCA|   1236|
# |         COD|  69180|
# +------------+-------+
# only showing top 20 rows
#
# iso3 Country Code Null Count:
# 0

# %% [markdown]
# ## <span style="color: white; font-weight: bold; text-decoration: underline;">sector</span>
# The sector is the economic sector that the activity belongs to
#
# Data Type: `string`
#
# **Status: <span style="color: red;">READY</span>**
#
# Problems: None

# %%
# Sector Exploration
column_title = "Sector"
column_name = "sector"


# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
    df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Sector Data Type
# StringType()
#
# Sector Head Values:
# +-----------+
# |     sector|
# +-----------+
# |agriculture|
# |agriculture|
# |agriculture|
# |agriculture|
# |agriculture|
# +-----------+
# only showing top 5 rows
#
# Sector Tail Values:
# +------+
# |sector|
# +------+
# | waste|
# | waste|
# | waste|
# | waste|
# | waste|
# +------+
# only showing top 5 rows
#
# Sector Distinct Values:
# +--------------------+
# |              sector|
# +--------------------+
# |  mineral-extraction|
# |               power|
# |         agriculture|
# |fossil-fuel-opera...|
# |               waste|
# |       manufacturing|
# |forestry-and-land...|
# |      transportation|
# |           buildings|
# +--------------------+
#
# Sector Count:
# 15184500
#
# Sector Value Counts:
# +--------------------+-------+
# |              sector|  count|
# +--------------------+-------+
# |  mineral-extraction|  19908|
# |               power| 106440|
# |         agriculture|5213832|
# |fossil-fuel-opera...|  60804|
# |               waste| 777072|
# |       manufacturing| 423876|
# |forestry-and-land...|6189372|
# |      transportation|1022112|
# |           buildings|1371084|
# +--------------------+-------+
#
# Sector Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">subsector</span>
# The subsector is the economic subsector that the activity belongs to.
#
# Data Type: `string`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems: None

# %%
# Subsector Exploration
column_title = "Subsector"
column_name = "subsector"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Subsector Data Type
# StringType()
#
# Subsector Head Values:
# +--------------+
# |     subsector|
# +--------------+
# |cropland-fires|
# |cropland-fires|
# |cropland-fires|
# |cropland-fires|
# |cropland-fires|
# +--------------+
# only showing top 5 rows
#
# Subsector Tail Values:
# +-------------+
# |    subsector|
# +-------------+
# |wetland-fires|
# |wetland-fires|
# |wetland-fires|
# |wetland-fires|
# |wetland-fires|
# +-------------+
# only showing top 5 rows
#
# Subsector Distinct Values:
# +--------------------+
# |           subsector|
# +--------------------+
# |      cropland-fires|
# |         net-wetland|
# |      bauxite-mining|
# |            aluminum|
# |   domestic-aviation|
# |food-beverage-tob...|
# |      iron-and-steel|
# |               glass|
# |           chemicals|
# |industrial-wastew...|
# |      net-shrubgrass|
# |                lime|
# |         iron-mining|
# |forest-land-degra...|
# |international-avi...|
# |enteric-fermentat...|
# |     net-forest-land|
# |domestic-wastewat...|
# |enteric-fermentat...|
# |         coal-mining|
# +--------------------+
# only showing top 20 rows
#
# Subsector Count:
# 15184500
#
# Subsector Value Counts:
# +--------------------+------+
# |           subsector| count|
# +--------------------+------+
# |      cropland-fires|688584|
# |         net-wetland|697776|
# |      bauxite-mining|  3168|
# |            aluminum|  2616|
# |   domestic-aviation| 58920|
# |food-beverage-tob...|177228|
# |      iron-and-steel| 10728|
# |               glass|  7668|
# |           chemicals|  4452|
# |industrial-wastew...| 15312|
# |      net-shrubgrass|719748|
# |                lime| 19308|
# |         iron-mining|  8664|
# |forest-land-degra...|638496|
# |international-avi...| 58920|
# |enteric-fermentat...|932736|
# |     net-forest-land|717120|
# |domestic-wastewat...|646260|
# |enteric-fermentat...|642888|
# |         coal-mining| 45456|
# +--------------------+------+
# only showing top 20 rows
#
# Subsector Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">original_inventory_sector</span>
# The original inventory sector is the economic sector that the activity belongs to.
#
# Data Type: `string`
#
# **Status: <span style="color: red;">NOT READY</span>**
#
# Problems:
# 1. does not have any value across all the datasets

# %%
# Original Inventory Sector Exploration
column_title = "Original Inventory"
column_name = "original_inventory_sector"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Original Inventory Data Type
# StringType()
#
# Original Inventory Head Values:
# +-------------------------+
# |original_inventory_sector|
# +-------------------------+
# |                     NULL|
# |                     NULL|
# |                     NULL|
# |                     NULL|
# |                     NULL|
# +-------------------------+
# only showing top 5 rows
#
# Original Inventory Tail Values:
# +-------------------------+
# |original_inventory_sector|
# +-------------------------+
# |                     NULL|
# |                     NULL|
# |                     NULL|
# |                     NULL|
# |                     NULL|
# +-------------------------+
# only showing top 5 rows
#
# Original Inventory Distinct Values:
# +-------------------------+
# |original_inventory_sector|
# +-------------------------+
# |                     NULL|
# +-------------------------+
#
# Original Inventory Count:
# 15184500
#
# Original Inventory Value Counts:
# +-------------------------+--------+
# |original_inventory_sector|   count|
# +-------------------------+--------+
# |                     NULL|15184500|
# +-------------------------+--------+
#
# Original Inventory Null Count:
# 15184500

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">start_time</span>
# The start time of the activity.
#
# Data Type: `timestamp`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems: None

# %%
# Start Time Exploration
column_title = "Start Time"
column_name = "start_time"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Start Time Data Type
# TimestampType()
#
# Start Time Head Values:
# +-------------------+
# |         start_time|
# +-------------------+
# |2021-09-01 00:00:00|
# |2021-10-01 00:00:00|
# |2021-11-01 00:00:00|
# |2021-12-01 00:00:00|
# |2021-01-01 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# Start Time Tail Values:
# +-------------------+
# |         start_time|
# +-------------------+
# |2021-12-01 00:00:00|
# |2021-12-01 00:00:00|
# |2021-12-01 00:00:00|
# |2021-12-01 00:00:00|
# |2021-12-01 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+-------------------+
# |          Max Value|          Min Value|
# +-------------------+-------------------+
# |2021-12-01 00:00:00|2021-01-01 00:00:00|
# +-------------------+-------------------+
#
# Start Time Count:
# 15184500
#
# Start Time Value Counts:
# +-------------------+-------+
# |         start_time|  count|
# +-------------------+-------+
# |2021-07-01 00:00:00|1265375|
# |2021-03-01 00:00:00|1265375|
# |2021-11-01 00:00:00|1265375|
# |2021-01-01 00:00:00|1265375|
# |2021-04-01 00:00:00|1265375|
# |2021-06-01 00:00:00|1265375|
# |2021-05-01 00:00:00|1265375|
# |2021-09-01 00:00:00|1265375|
# |2021-10-01 00:00:00|1265375|
# |2021-12-01 00:00:00|1265375|
# |2021-02-01 00:00:00|1265375|
# |2021-08-01 00:00:00|1265375|
# +-------------------+-------+
#
# Start Time Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">end_time</span>
# The end time of the activity.
#
# Data Type: `timestamp`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems: None

# %%
# End Time Exploration
column_title = "End Time"
column_name = "end_time"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# End Time Data Type
# TimestampType()
#
# End Time Head Values:
# +-------------------+
# |           end_time|
# +-------------------+
# |2021-09-30 00:00:00|
# |2021-10-31 00:00:00|
# |2021-11-30 00:00:00|
# |2021-12-31 00:00:00|
# |2021-01-31 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# End Time Tail Values:
# +-------------------+
# |           end_time|
# +-------------------+
# |2021-12-31 00:00:00|
# |2021-12-31 00:00:00|
# |2021-12-31 00:00:00|
# |2021-12-31 00:00:00|
# |2021-12-31 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+-------------------+
# |          Max Value|          Min Value|
# +-------------------+-------------------+
# |2021-12-31 00:00:00|2021-01-31 00:00:00|
# +-------------------+-------------------+
#
# End Time Count:
# 15184500
#
# End Time Value Counts:
# +-------------------+-------+
# |           end_time|  count|
# +-------------------+-------+
# |2021-09-30 00:00:00|1265375|
# |2021-01-31 00:00:00|1265375|
# |2021-03-31 00:00:00|1265375|
# |2021-02-28 00:00:00|1265375|
# |2021-10-31 00:00:00|1265375|
# |2021-05-31 00:00:00|1265375|
# |2021-07-31 00:00:00|1265375|
# |2021-08-31 00:00:00|1265375|
# |2021-12-31 00:00:00|1265375|
# |2021-04-30 00:00:00|1265375|
# |2021-11-30 00:00:00|1265375|
# |2021-06-30 00:00:00|1265375|
# +-------------------+-------+
#
# End Time Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">temporal_granularity</span>
# The temporal granularity of the activity.
#
# Data Type: `string`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems:
# 1. The granularity of the observations were on a monthly scale. Therefore, this field is unnecessary and is mainly redundant. This can be added in the documentation instead.

# %%
# Temporal Granularity Exploration
column_title = "Temporal Granularity"
column_name = "temporal_granularity"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Temporal Granularity Data Type
# StringType()
#
# Temporal Granularity Head Values:
# +--------------------+
# |temporal_granularity|
# +--------------------+
# |               month|
# |               month|
# |               month|
# |               month|
# |               month|
# +--------------------+
# only showing top 5 rows
#
# Temporal Granularity Tail Values:
# +--------------------+
# |temporal_granularity|
# +--------------------+
# |               month|
# |               month|
# |               month|
# |               month|
# |               month|
# +--------------------+
# only showing top 5 rows
#
# Temporal Granularity Distinct Values:
# +--------------------+
# |temporal_granularity|
# +--------------------+
# |               month|
# +--------------------+
#
# Temporal Granularity Count:
# 15184500
#
# Temporal Granularity Value Counts:
# +--------------------+--------+
# |temporal_granularity|   count|
# +--------------------+--------+
# |               month|15184500|
# +--------------------+--------+
#
# Temporal Granularity Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">gas</span>
# The gas type observed in the activity.
#
# Data Type: `string`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems:
# 1. label should be renamed to something more descriptive like gas type

# %%
# Gas Type Exploration
column_title = "Gas Type"
column_name = "gas"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Gas Type Data Type
# StringType()
#
# Gas Type Head Values:
# +---+
# |gas|
# +---+
# |ch4|
# |ch4|
# |ch4|
# |ch4|
# |ch4|
# +---+
# only showing top 5 rows
#
# Gas Type Tail Values:
# +---+
# |gas|
# +---+
# |ch4|
# |ch4|
# |ch4|
# |ch4|
# |ch4|
# +---+
# only showing top 5 rows
#
# Gas Type Distinct Values:
# +---+
# |gas|
# +---+
# |ch4|
# +---+
#
# Gas Type Count:
# 15184500
#
# Gas Type Value Counts:
# +---+--------+
# |gas|   count|
# +---+--------+
# |ch4|15184500|
# +---+--------+
#
# Gas Type Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">emissions_quantity</span>
# The emissions quantity of the activity.
#
# Data Type: `double`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems: None

# %%
# Emissions Quantity Exploration
column_title = "Emissions Quantity"
column_name = "emissions_quantity"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Emissions Quantity Data Type
# DoubleType()
#
# Emissions Quantity Head Values:
# +------------------+
# |emissions_quantity|
# +------------------+
# |1.7397360595540778|
# | 2.421369167131417|
# | 1.637782823959021|
# |0.5098989112747037|
# |0.1230362365371346|
# +------------------+
# only showing top 5 rows
#
# Emissions Quantity Tail Values:
# +------------------+
# |emissions_quantity|
# +------------------+
# |1006126.2679489036|
# | 991152.2025790858|
# |  959186.759272008|
# | 786601.1066666663|
# | 786601.1066666663|
# +------------------+
# only showing top 5 rows
#
# +------------------+---------+
# |         Max Value|Min Value|
# +------------------+---------+
# |1006126.2679489036|      0.0|
# +------------------+---------+
#
# Emissions Quantity Count:
# 15184500
#
# Emissions Quantity Value Counts:
# +------------------+-----+
# |emissions_quantity|count|
# +------------------+-----+
# |0.2131887694573457|    1|
# |0.0057017587950824|    1|
# |1.3698845721110051|    1|
# | 6.572309787900159|    1|
# | 2.823555703637906|    1|
# |24.874220402046696|    1|
# | 0.003203156526665|    1|
# |0.0203901567686673|    1|
# |0.0041510826788253|    1|
# |0.0354636156441163|    1|
# |0.1660120727622066|    1|
# |0.0066326746110835|    1|
# | 8.802513405776E-4|    1|
# | 2.299222190714885|    2|
# |0.3434026127478791|    2|
# |0.5525486642989096|    2|
# | 53.55371964747854|    2|
# | 0.065827246919873|    2|
# |0.3987815444012101|    2|
# |1.3092075325593162|    2|
# +------------------+-----+
# only showing top 20 rows
#
# Emissions Quantity Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">emissions_factor</span>
# The emissions factor influencing the activity.
#
# Data Type: `double`
#
# **Status: <span style="color: green;">NOT READY</span>**
#
# Problems:
# 1. Has null or missing values

# %%
# Emissions Factor Exploration
column_title = "Emissions Factor"
column_name = "emissions_factor"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Emissions Factor Data Type
# DoubleType()
#
# Emissions Factor Head Values:
# +----------------+
# |emissions_factor|
# +----------------+
# |          0.0023|
# |          0.0023|
# |          0.0023|
# |          0.0023|
# |          0.0023|
# +----------------+
# only showing top 5 rows
#
# Emissions Factor Tail Values:
# +----------------+
# |emissions_factor|
# +----------------+
# |         5261.26|
# |         5261.26|
# |         5261.26|
# |         5261.26|
# |         5261.26|
# +----------------+
# only showing top 5 rows
#
# +---------+---------+
# |Max Value|Min Value|
# +---------+---------+
# |  5261.26|      0.0|
# +---------+---------+
#
# Emissions Factor Count:
# 15184500
#
# Emissions Factor Value Counts:
# +--------------------+-----+
# |    emissions_factor|count|
# +--------------------+-----+
# |   1.953000013768E-4|    2|
# |   1.952999999759E-4|   10|
# |2.934000000134208E-5|    3|
# |3.031800007618303...|    1|
# |   1.822799869558E-4|   11|
# |3.031800006580577E-5|    1|
# |    1.95299999355E-4|    1|
# |3.031800007218973E-5|    1|
# |3.031799970358137E-5|    1|
# |3.031800003796014...|    1|
# |2.933999989933813...|    1|
# |2.812319981881820...|    1|
# |3.381480032987112E-5|    1|
# |2.812319977235436E-5|    1|
# |3.381480119726552...|    1|
# | 3.38147916697167E-5|    1|
# |2.812320007445887...|    1|
# |3.031800176233504E-5|    1|
# |3.381481007869166...|    1|
# |2.721600029713666...|    1|
# +--------------------+-----+
# only showing top 20 rows
#
# Emissions Factor Null Count:
# 6864

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">capacity</span>
# This field has unknown description of purpose and use.
#
# Data Type: `double`
#
# **Status: <span style="color: red;">NOT READY</span>**
#
# Problems:
# 1. has null or missing values
# 2. has infinity value

# %%
# Capacity Exploration
column_title = "Capacity"
column_name = "capacity"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Capacity Data Type
# DoubleType()
#
# Capacity Head Values:
# +-----------------+
# |         capacity|
# +-----------------+
# | 5301.96148042613|
# | 5301.96148042613|
# | 5301.96148042613|
# | 5301.96148042613|
# |6030.153967362565|
# +-----------------+
# only showing top 5 rows
#
# Capacity Tail Values:
# +--------+
# |capacity|
# +--------+
# |Infinity|
# |Infinity|
# |Infinity|
# |Infinity|
# |Infinity|
# +--------+
# only showing top 5 rows
#
# +---------+---------+
# |Max Value|Min Value|
# +---------+---------+
# | Infinity|      0.0|
# +---------+---------+
#
# Capacity Count:
# 15184500
#
# Capacity Value Counts:
# +------------------+-----+
# |          capacity|count|
# +------------------+-----+
# |4217.6684399571695|   12|
# |100945.90280949564|   12|
# | 58.00026352808783|   12|
# |  585.257357291574|   12|
# |  50383.3640869687|   12|
# | 87480.62672733956|   12|
# |124949.84508174176|   12|
# | 819280.8600828913|   12|
# |1600.2870372706695|   12|
# | 26.80405370168061|   12|
# | 522.5614839493696|   12|
# |19.225170125755827|   12|
# |1413.5574512874305|   12|
# |247.64055251986343|   12|
# | 4849.159447174913|   12|
# | 3783.095075718552|   12|
# | 952.7167832937564|   12|
# | 40534.44855093861|   12|
# |202.82115321599045|   12|
# | 5.529316326685782|   12|
# +------------------+-----+
# only showing top 20 rows
#
# Capacity Null Count:
# 6864

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">capacity_factor</span>
# The factor affecting capacity.
#
# Data Type: `double`
#
# **Status: <span style="color: red;">NOT READY</span>**
#
# Problems:
# 1. has null or missing values

# %%
# Capacity Factor Exploration
column_title = "Capacity Factor"
column_name = "capacity_factor"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
    df.agg(
        max(col(column_name)).alias("Max Value"),
        min(col(column_name)).alias("Min Value")
    ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Capacity Factor Data Type
# DoubleType()
#
# Capacity Factor Head Values:
# +------------------+
# |   capacity_factor|
# +------------------+
# | 0.142665499401935|
# |  0.19856221268058|
# |  0.13430491551225|
# |0.0418138041239165|
# |0.0088710862401259|
# +------------------+
# only showing top 5 rows
#
# Capacity Factor Tail Values:
# +--------------------+
# |     capacity_factor|
# +--------------------+
# |1.2577829880592796E8|
# |1.2577829880592796E8|
# |1.2577829880592796E8|
# |1.2577829880592796E8|
# |1.2577829880592796E8|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+---------+
# |           Max Value|Min Value|
# +--------------------+---------+
# |1.2577829880592796E8|      0.0|
# +--------------------+---------+
#
# Capacity Factor Count:
# 15184500
#
# Capacity Factor Value Counts:
# +------------------+-----+
# |   capacity_factor|count|
# +------------------+-----+
# |0.0493137328376579|   91|
# |0.8575212832036246|   21|
# |0.0406823255813953|   12|
# |0.3749607142857143|    1|
# |0.0382572727272727|    1|
# |       0.899515625|    2|
# |0.0389174999999999|    6|
# |0.8057677272727272|    1|
# |          0.510975|    3|
# |0.8209612500000001|    2|
# |0.5120333333333333|    2|
# |         0.5113625|    4|
# |0.8960307692307692|    1|
# |0.8209741666666668|    2|
# |0.9424607142857142|    1|
# |            0.9523|    3|
# |0.6416333333333334|    1|
# |          0.392154|    3|
# |0.5106333333333334|    2|
# |0.0387692857142857|    3|
# +------------------+-----+
# only showing top 20 rows
#
# Capacity Factor Null Count:
# 6864

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">activity</span>
# The number or counto of major activities resulting the emissions.
#
# Data Type: `double`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems:
# 1. has null or missing values

# %%
# Activity Exploration
column_title = "Activity"
column_name = "activity"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Activity Data Type
# DoubleType()
#
# Activity Head Values:
# +------------------+
# |          activity|
# +------------------+
# | 756.4069824148164|
# | 1052.769203100616|
# | 712.0794886778352|
# |221.69517881508847|
# | 53.49401588571072|
# +------------------+
# only showing top 5 rows
#
# Activity Tail Values:
# +--------------------+
# |            activity|
# +--------------------+
# |7.462960084532733E11|
# |7.462960084532733E11|
# |7.462960084532733E11|
# |7.332167392579166E11|
# |7.332167392579166E11|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+---------+
# |           Max Value|Min Value|
# +--------------------+---------+
# |7.462960084532733E11|      0.0|
# +--------------------+---------+
#
# Activity Count:
# 15184500
#
# Activity Value Counts:
# +------------------+-----+
# |          activity|count|
# +------------------+-----+
# |210.16141074308769|    1|
# | 219.1031731191849|    1|
# | 208.9688036307177|    1|
# |429.30412158170657|    1|
# | 26.39082389959608|    1|
# |285.60865348012084|    1|
# | 38.94160095112392|    1|
# | 4704.396085228726|    1|
# |   266.62472200094|    1|
# | 640.8810642718123|    1|
# | 3.799954812447411|    1|
# |21.817637891104336|    1|
# | 82.90283812687248|    1|
# | 3.085570410402779|    1|
# |490.27047386715407|    1|
# | 8.816308554055425|    1|
# | 963.5515414040088|    1|
# |0.2322900313326275|    1|
# | 69.11731561800846|    2|
# | 916.2694232841249|    2|
# +------------------+-----+
# only showing top 20 rows
#
# Activity Null Count:
# 6864

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">source_name</span>
# The name of the data source.
#
# Data Type: `string`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems:
# 1. has null or missing values

# %%
# Source Name Exploration
column_title = "Source Name"
column_name = "source_name"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Source Name Data Type
# StringType()
#
# Source Name Head Values:
# +-----------+
# |source_name|
# +-----------+
# |   Ala-Buka|
# |   Ala-Buka|
# |   Ala-Buka|
# |   Ala-Buka|
# |       Alai|
# +-----------+
# only showing top 5 rows
#
# Source Name Tail Values:
# +-----------+
# |source_name|
# +-----------+
# |       웅상|
# |       웅상|
# |       웅상|
# |       웅상|
# |       웅상|
# +-----------+
# only showing top 5 rows
#
# Source Name Distinct Values:
# +--------------------+
# |         source_name|
# +--------------------+
# |            Vilniaus|
# |            Coapilla|
# |Santa Ana Ateixtl...|
# |        Villahermosa|
# |            Xicotlán|
# |           Bar Kunar|
# |           Bolyarovo|
# |        Borrazópolis|
# |              Pongaí|
# |    Agapovskiy rayon|
# |  Kardymovskiy rayon|
# |               Topki|
# |         Tejutepeque|
# |             Na Thom|
# |Le Haut-Saint-Fra...|
# |     Le Rocher-Percé|
# |            Donggang|
# |           Kisangani|
# |            Fredonia|
# |            Girardot|
# +--------------------+
# only showing top 20 rows
#
# Source Name Count:
# 15184500
#
# Source Name Value Counts:
# +--------------------+-----+
# |         source_name|count|
# +--------------------+-----+
# |            Vilniaus|  408|
# |            Coapilla|  204|
# |Santa Ana Ateixtl...|  192|
# |        Villahermosa|  408|
# |            Xicotlán|  192|
# |           Bar Kunar|  204|
# |           Bolyarovo|  204|
# |        Borrazópolis|  204|
# |              Pongaí|  204|
# |    Agapovskiy rayon|  204|
# |  Kardymovskiy rayon|  204|
# |               Topki|  204|
# |         Tejutepeque|  192|
# |             Na Thom|  204|
# |Le Haut-Saint-Fra...|  204|
# |     Le Rocher-Percé|  204|
# |            Donggang|  180|
# |           Kisangani|  348|
# |            Fredonia|  204|
# |            Girardot|  792|
# +--------------------+-----+
# only showing top 20 rows
#
# Source Name Null Count:
# 96768

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">source_type</span>
# The industry or service type of source.
#
# Data Type: `string`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems:
# 1. has null or missing values

# %%
# Source Type Exploration
column_title = "Source Type"
column_name = "source_type"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Source Type Data Type
# StringType()
#
# Source Type Head Values:
# +-----------+
# |source_type|
# +-----------+
# |       NULL|
# |       NULL|
# |       NULL|
# |       NULL|
# |       NULL|
# +-----------+
# only showing top 5 rows
#
# Source Type Tail Values:
# +---------------+
# |    source_type|
# +---------------+
# |zinc_production|
# |zinc_production|
# |zinc_production|
# |zinc_production|
# |zinc_production|
# +---------------+
# only showing top 5 rows
#
# Source Type Distinct Values:
# +--------------------+
# |         source_type|
# +--------------------+
# |      DRI-EAF,BF/BOF|
# |manufacturer | Li...|
# |Meat Processing| ...|
# |Certification - E...|
# |coal, other_fossi...|
# |Certification - E...|
# |       biomass, coal|
# |Imported Product|...|
# |Meat Processing| ...|
# |Identification - ...|
# |manufacturer | Li...|
# |manufacturer | Li...|
# |Certification - E...|
# |Identification - ...|
# |Certification - E...|
# |Meat Processing| ...|
# |Meat Processing| ...|
# |enteric_fermentat...|
# |Meat Processing| ...|
# |Meat Processing| ...|
# +--------------------+
# only showing top 20 rows
#
# Source Type Count:
# 15184500
#
# Source Type Value Counts:
# +--------------------+------+
# |         source_type| count|
# +--------------------+------+
# |      DRI-EAF,BF/BOF|    12|
# |manufacturer | Li...|    12|
# |Meat Processing| ...|    96|
# |Certification - E...|    24|
# |coal, other_fossi...|    24|
# |Certification - E...|    12|
# |       biomass, coal|   240|
# |Imported Product|...|    12|
# |Meat Processing| ...|    24|
# |Identification - ...|    12|
# |manufacturer | Li...|    60|
# |manufacturer | Li...|    12|
# |Certification - E...|    12|
# |Identification - ...|    12|
# |Certification - E...|   228|
# |Meat Processing| ...|    24|
# |Meat Processing| ...|    12|
# |enteric_fermentat...|420936|
# |Meat Processing| ...|    84|
# |Meat Processing| ...|    48|
# +--------------------+------+
# only showing top 20 rows
#
# Source Type Null Count:
# 11739708

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">geometry_ref</span>
# Geometry reference id of the area being observed
#
# Data Type: `string`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems: None

# %%
# Geometry Reference Exploration
column_title = "Geometry Reference"
column_name = "geometry_ref"

# Data Type
print(f"{column_title} Data Type")
data_type = df.schema[column_name].dataType
print(data_type)

# Head
print(f"\n{column_title} Head Values:")
df.select(column_name).show(5)

# Tail
print(f"{column_title} Tail Values:")
df.select(column_name).orderBy(column_name, ascending=False).show(5)

# Min and Max
if not isinstance(data_type, StringType):
  df.agg(
      max(col(column_name)).alias("Max Value"),
      min(col(column_name)).alias("Min Value")
  ).show()

# Distinct
if isinstance(data_type, StringType):
    print(f"{column_title} Distinct Values:")
    df.select(column_name).distinct().show()

    print(f"{column_title} Distinct Count:")
    print(df.select(column_name).distinct().count())

# Total Count
print(f"{column_title} Count:")
print(df.select(column_name).count())

# Value Count
print(f"\n{column_title} Value Counts:")
df.groupBy(column_name).count().show()

# Null Count
print(f"{column_title} Null Count:")
print(df.filter(col(column_name).isNull()).count())
# Out:
# Geometry Reference Data Type
# StringType()
#
# Geometry Reference Head Values:
# +--------------+
# |  geometry_ref|
# +--------------+
# |gadm_KGZ.4.2_1|
# |gadm_KGZ.4.2_1|
# |gadm_KGZ.4.2_1|
# |gadm_KGZ.4.2_1|
# |gadm_KGZ.7.1_1|
# +--------------+
# only showing top 5 rows
#
# Geometry Reference Tail Values:
# +------------+
# |geometry_ref|
# +------------+
# |   trace_923|
# |   trace_923|
# |   trace_923|
# |   trace_923|
# |   trace_923|
# +------------+
# only showing top 5 rows
#
# Geometry Reference Distinct Values:
# +-----------------+
# |     geometry_ref|
# +-----------------+
# |     gadm_KGZ.9_1|
# |gadm_MEX.20.393_2|
# |gadm_MEX.20.413_2|
# | gadm_MEX.29.59_2|
# |  gadm_AFG.22.2_1|
# |     gadm_AND.4_1|
# | gadm_ARG.14.14_1|
# |   trace_37161875|
# |  gadm_BOL.7.16_2|
# |  gadm_BRA.4.13_2|
# | gadm_ROU.11.71_1|
# |   gadm_SAU.3.4_1|
# |   gadm_TLS.9.3_1|
# |   trace_37178287|
# |  gadm_COD.11.5_1|
# |  gadm_COD.17.6_1|
# |   trace_37188277|
# |   gadm_ECU.2.3_1|
# |   trace_37234621|
# |   trace_37185790|
# +-----------------+
# only showing top 20 rows
#
# Geometry Reference Count:
# 15184500
#
# Geometry Reference Value Counts:
# +-----------------+-----+
# |     geometry_ref|count|
# +-----------------+-----+
# |     gadm_KGZ.9_1|  204|
# |gadm_MEX.20.393_2|  168|
# |gadm_MEX.20.413_2|  180|
# | gadm_MEX.29.59_2|  180|
# |  gadm_AFG.22.2_1|  204|
# |     gadm_AND.4_1|  180|
# | gadm_ARG.14.14_1|  204|
# |   trace_37161875|   12|
# |  gadm_BOL.7.16_2|  192|
# |  gadm_BRA.4.13_2|  204|
# | gadm_ROU.11.71_1|  204|
# |   gadm_SAU.3.4_1|  192|
# |   gadm_TLS.9.3_1|  192|
# |   trace_37178287|   12|
# |  gadm_COD.11.5_1|  192|
# |  gadm_COD.17.6_1|  192|
# |   trace_37188277|   12|
# |   gadm_ECU.2.3_1|  204|
# |   trace_37234621|   12|
# |   trace_37185790|   12|
# +-----------------+-----+
# only showing top 20 rows
#
# Geometry Reference Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">Metric Units</span>
# Units of measurement used for each metric
#
# Data Type: `string`
#
# **Status: <span style="color: green;">READY</span>**
#
# Problems:
# 1. The units are the same across all datasets and this overhead can be minimized by adding it to the field's label.

# %%
# Metric Units Exploration
metric_fields = {
    "emissions_factor_units": "Emissions Factor Units",
    "capacity_units": "Capacity Units",
    "activity_units": "Activity Units"
}

for each in metric_fields:
    column_title = metric_fields[each]
    column_name = each

    print(f"""{column_name}
================================================================
""")

    print(f"{column_title} Data Type")
    data_type = df.schema[column_name].dataType
    print(data_type)

    print(f"{column_title} Head Values:")
    df.select(column_name).show(5)

    print(f"{column_title} Tail Values:")
    df.select(column_name).orderBy(column_name, ascending=False).show(5)

    if isinstance(data_type, StringType):
        print(f"{column_title} Distinct Values:")
        df.select(column_name).distinct().show()

        print(f"{column_title} Distinct Count:")
        print(df.select(column_name).distinct().count())

    print(f"{column_title} Count:")
    print(df.count())

    print(f"{column_title} Value Counts:")
    df.groupBy(column_name).count().show()

    print(f"{column_title} Null Count:")
    print(df.filter(col(column_name).isNull()).count())
# Out:
# emissions_factor_units
# ================================================================
#
# Emissions Factor Units Data Type
# StringType()
# Emissions Factor Units Head Values:
# +----------------------+
# |emissions_factor_units|
# +----------------------+
# |  t of CH4 per area...|
# |  t of CH4 per area...|
# |  t of CH4 per area...|
# |  t of CH4 per area...|
# |  t of CH4 per area...|
# +----------------------+
# only showing top 5 rows
#
# Emissions Factor Units Tail Values:
# +----------------------+
# |emissions_factor_units|
# +----------------------+
# |  t of CH4 per tonn...|
# |  t of CH4 per tonn...|
# |  t of CH4 per tonn...|
# |  t of CH4 per tonn...|
# |  t of CH4 per tonn...|
# +----------------------+
# only showing top 5 rows
#
# Emissions Factor Units Distinct Values:
# +----------------------+
# |emissions_factor_units|
# +----------------------+
# |  t of CH4 per t of...|
# |  t of CH4 per tonn...|
# |  t of CH4 per t of...|
# |  t of CH4 per t of...|
# |  t of CH4 per area...|
# |  t of CH4 per t of...|
# |  t of CH4 per anim...|
# |  t of CH4 per t of...|
# |  t of CH4 per t of...|
# |  t of CH4 per t of...|
# |      t of CH4 per USD|
# |  t of CH4 per t of...|
# |  t of CH4 per t of...|
# |  t of CH4 per t of...|
# |  t of CH4 per t of...|
# |  t of CH4 per naut...|
# |  t of CH4 per popu...|
# |      t of CH4 per MWh|
# |  t of CH4 per factory|
# |  t of CH4 per tonn...|
# +----------------------+
# only showing top 20 rows
#
# Emissions Factor Units Count:
# 15184500
# Emissions Factor Units Value Counts:
# +----------------------+-------+
# |emissions_factor_units|  count|
# +----------------------+-------+
# |  t of CH4 per t of...|  10728|
# |  t of CH4 per tonn...|  15312|
# |  t of CH4 per t of...|6104964|
# |  t of CH4 per t of...|   8664|
# |  t of CH4 per area...| 688584|
# |  t of CH4 per t of...|  26892|
# |  t of CH4 per anim...|3150564|
# |  t of CH4 per t of...|  19308|
# |  t of CH4 per t of...|   4452|
# |  t of CH4 per t of...| 117840|
# |      t of CH4 per USD| 338844|
# |  t of CH4 per t of...|   2616|
# |  t of CH4 per t of...|   3168|
# |  t of CH4 per t of...|   8076|
# |  t of CH4 per t of...|  45456|
# |  t of CH4 per naut...| 185388|
# |  t of CH4 per popu...| 646260|
# |      t of CH4 per MWh| 106440|
# |  t of CH4 per factory|  15060|
# |  t of CH4 per tonn...| 115500|
# +----------------------+-------+
# only showing top 20 rows
#
# Emissions Factor Units Null Count:
# 0
# capacity_units
# ================================================================
#
# Capacity Units Data Type
# StringType()
# Capacity Units Head Values:
# +--------------+
# |capacity_units|
# +--------------+
# |            ha|
# |            ha|
# |            ha|
# |            ha|
# |            ha|
# +--------------+
# only showing top 5 rows
#
# Capacity Units Tail Values:
# +-----------------+
# |   capacity_units|
# +-----------------+
# |voyages and stays|
# |voyages and stays|
# |voyages and stays|
# |voyages and stays|
# |voyages and stays|
# +-----------------+
# only showing top 5 rows
#
# Capacity Units Distinct Values:
# +--------------------+
# |      capacity_units|
# +--------------------+
# |              tonnes|
# |   tonnes of product|
# |         t of cement|
# |           t of lime|
# |t of CO2 in livin...|
# |                  ha|
# | t of iron and steel|
# |                  MW|
# |population equiva...|
# |       t of chemical|
# |             flights|
# |  t of coal per year|
# |   voyages and stays|
# |       t of aluminum|
# |      animal head(s)|
# |                 USD|
# |       t of ethylene|
# |                  km|
# |         BBL per day|
# |          restricted|
# +--------------------+
# only showing top 20 rows
#
# Capacity Units Count:
# 15184500
# Capacity Units Value Counts:
# +--------------------+-------+
# |      capacity_units|  count|
# +--------------------+-------+
# |              tonnes|  19908|
# |   tonnes of product|  15312|
# |         t of cement|  26892|
# |           t of lime|  19308|
# |t of CO2 in livin...|6104964|
# |                  ha|2063268|
# | t of iron and steel|  10728|
# |                  MW| 106440|
# |population equiva...| 646260|
# |       t of chemical|   4452|
# |             flights| 117840|
# |  t of coal per year|  45456|
# |   voyages and stays| 185388|
# |       t of aluminum|   2616|
# |      animal head(s)|3150564|
# |                 USD| 338844|
# |       t of ethylene|   2808|
# |                  km| 718884|
# |         BBL per day|   8484|
# |          restricted|   6864|
# +--------------------+-------+
# only showing top 20 rows
#
# Capacity Units Null Count:
# 0
# activity_units
# ================================================================
#
# Activity Units Data Type
# StringType()
# Activity Units Head Values:
# +--------------+
# |activity_units|
# +--------------+
# |     area [ha]|
# |     area [ha]|
# |     area [ha]|
# |     area [ha]|
# |     area [ha]|
# +--------------+
# only showing top 5 rows
#
# Activity Units Tail Values:
# +---------------+
# | activity_units|
# +---------------+
# |tonnes of waste|
# |tonnes of waste|
# |tonnes of waste|
# |tonnes of waste|
# |tonnes of waste|
# +---------------+
# only showing top 5 rows
#
# Activity Units Distinct Values:
# +--------------------+
# |      activity_units|
# +--------------------+
# |      nautical miles|
# |   tonnes of product|
# |           t of coal|
# |         t of cement|
# |           t of lime|
# |                 MWh|
# | t of iron and steel|
# |population equiva...|
# |       t of chemical|
# |           area [ha]|
# |t of CO2 in livin...|
# |           t of fuel|
# |       t of aluminum|
# |      animal head(s)|
# |    t of bauxite ore|
# |     t of copper ore|
# |                 USD|
# |       t of iron ore|
# |  tonnes of ethylene|
# |     tonnes of waste|
# +--------------------+
# only showing top 20 rows
#
# Activity Units Count:
# 15184500
# Activity Units Value Counts:
# +--------------------+-------+
# |      activity_units|  count|
# +--------------------+-------+
# |      nautical miles| 185388|
# |   tonnes of product|  15312|
# |           t of coal|  45456|
# |         t of cement|  26892|
# |           t of lime|  19308|
# |                 MWh| 106440|
# | t of iron and steel|  10728|
# |population equiva...| 646260|
# |       t of chemical|   4452|
# |           area [ha]| 688584|
# |t of CO2 in livin...|6104964|
# |           t of fuel| 117840|
# |       t of aluminum|   2616|
# |      animal head(s)|3150564|
# |    t of bauxite ore|   3168|
# |     t of copper ore|   8076|
# |                 USD| 338844|
# |       t of iron ore|   8664|
# |  tonnes of ethylene|   2808|
# |     tonnes of waste| 115500|
# +--------------------+-------+
# only showing top 20 rows
#
# Activity Units Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">lat and lon</span>
# Coordinates of the source
#
# Data Type: `double`
#
# **Status: <span style="color: read;">NOT READY</span>**
#
# Problems:
# 1. Longitude fields have missing values.
# 2. Latitude fields have missing values.

# %%
# Latitude and Longitude Exploration
metric_fields = {
    "lat": "Latitude",
    "lon": "Longitude"
}

for each in metric_fields:
    column_title = metric_fields[each]
    column_name = each

    print(f"""\n
================================================================
    {column_name}
================================================================
""")

    print(f"{column_title} Data Type")
    data_type = df.schema[column_name].dataType
    print(data_type)

    print(f"{column_title} Head Values:")
    df.select(column_name).show(5)

    print(f"{column_title} Tail Values:")
    df.select(column_name).orderBy(column_name, ascending=False).show(5)

    if isinstance(data_type, StringType):
        print(f"{column_title} Distinct Values:")
        df.select(column_name).distinct().show()

        print(f"{column_title} Distinct Count:")
        print(df.select(column_name).distinct().count())

    print(f"{column_title} Count:")
    print(df.count())

    print(f"{column_title} Value Counts:")
    df.groupBy(column_name).count().show()

    print(f"{column_title} Null Count:")
    print(df.filter(col(column_name).isNull()).count())
# Out:
# ================================================================
#     lat
# ================================================================
#
# Latitude Data Type
# DoubleType()
# Latitude Head Values:
# +-----------------+
# |              lat|
# +-----------------+
# |41.41383005758116|
# |41.41383005758116|
# |41.41383005758116|
# |41.41383005758116|
# |39.85186444062204|
# +-----------------+
# only showing top 5 rows
#
# Latitude Tail Values:
# +----------------+
# |             lat|
# +----------------+
# |80.7068335565229|
# |80.7068335565229|
# |80.7068335565229|
# |80.7068335565229|
# |80.7068335565229|
# +----------------+
# only showing top 5 rows
#
# Latitude Count:
# 15184500
# Latitude Value Counts:
# +-------------------+-----+
# |                lat|count|
# +-------------------+-----+
# | 42.716402701454015|  204|
# | 17.396693570568917|  204|
# |  19.55551914932812|  204|
# |  18.22474547105624|  192|
# | 17.213799048555995|  204|
# |  35.76691695635098|  204|
# |  41.83304253212797|  204|
# |  42.36884433678797|  204|
# |  25.43935849616272|  192|
# |-13.519109790014776|  192|
# | -22.44773567020908|  204|
# |  44.39115468908935|  204|
# |  52.65748874386815|  204|
# |  40.16504565450128|  204|
# |  5.386796430795163|  204|
# | 3.8555095459229154|  204|
# | -4.167820932215766|  204|
# |  41.70169633698679|  408|
# |  36.67797935851969|  204|
# |  8.330852374019997|  204|
# +-------------------+-----+
# only showing top 20 rows
#
# Latitude Null Count:
# 1389924
#
#
# ================================================================
#     lon
# ================================================================
#
# Longitude Data Type
# DoubleType()
# Longitude Head Values:
# +-----------------+
# |              lon|
# +-----------------+
# |71.20585466776532|
# |71.20585466776532|
# |71.20585466776532|
# |71.20585466776532|
# |73.45181530358343|
# +-----------------+
# only showing top 5 rows
#
# Longitude Tail Values:
# +--------+
# |     lon|
# +--------+
# |179.9116|
# |179.9116|
# |179.9116|
# |179.9116|
# |179.9116|
# +--------+
# only showing top 5 rows
#
# Longitude Count:
# 15184500
# Longitude Value Counts:
# +-------------------+-----+
# |                lon|count|
# +-------------------+-----+
# | -96.71877370382174|  192|
# |   94.3852612785076|  192|
# |-63.870374161270746|  204|
# | 10.896556669964667|  204|
# | 14.295537858998989|  204|
# | 10.483080922190798|  204|
# | -49.65245191669477|  204|
# | -42.18700787545959|  204|
# | -51.78041427028141|  204|
# | 27.171206026463768|  192|
# | -89.73088558003712|  204|
# | 14.627982684123271|  204|
# |  16.14622279480453|  180|
# | 125.39904194348333|  192|
# | -73.32513387290666|  204|
# |  8.942777314479201|  204|
# |  1.189111011104248|  204|
# | 177.42694594283955|  168|
# |  42.63258065524635|  204|
# | -79.91286393330213|  204|
# +-------------------+-----+
# only showing top 20 rows
#
# Longitude Null Count:
# 1389924

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">Other Metadata</span>
# Metadata of the each record, i.e. latitude and longitude
#
# Data Type: `string`
#
# **Status: <span style="color: read;">NOT READY</span>**
#
# Problems:
# 1. Metadata are inconsistent
# 2. Metadata have massive missing values that cannot be imputed
#
# These inconsistencies have irregular patterns across the datasets.

# %%
# Other Fields Value Exploration
metric_fields = {f"other{i + 1}": f"Other{i + 1}" for i in range(12)}

for column_name, column_title in metric_fields.items():
    print(f"""{column_name}
================================================================
""")

    print(f"{column_title} Data Type")
    data_type = df.schema[column_name].dataType
    print(data_type)

    print(f"{column_title} Head Values:")
    df.select(column_name).show(5)

    print(f"{column_title} Tail Values:")
    df.select(column_name).orderBy(column_name, ascending=False).show(5)

    if isinstance(data_type, StringType):
        print(f"{column_title} Distinct Values:")
        df.select(column_name).distinct().show()

        print(f"{column_title} Distinct Count:")
        print(df.select(column_name).distinct().count())

    print(f"{column_title} Count:")
    print(df.count())

    print(f"{column_title} Value Counts:")
    df.groupBy(column_name).count().show()

    print(f"{column_title} Null Count:")
    print(df.filter(col(column_name).isNull()).count())
# Out:
# other1
# ================================================================
#
# Other1 Data Type
# StringType()
# Other1 Head Values:
# +-------+
# | other1|
# +-------+
# |KGZ.4_1|
# |KGZ.4_1|
# |KGZ.4_1|
# |KGZ.4_1|
# |KGZ.7_1|
# +-------+
# only showing top 5 rows
#
# Other1 Tail Values:
# +---------------+
# |         other1|
# +---------------+
# |zinc_production|
# |zinc_production|
# |zinc_production|
# |zinc_production|
# |zinc_production|
# +---------------+
# only showing top 5 rows
#
# Other1 Distinct Values:
# +------------------+
# |            other1|
# +------------------+
# |          AFG.28_1|
# |          RUS.26_1|
# |          TUR.56_1|
# |          DOM.24_1|
# |          DZA.45_1|
# |           ESP.4_1|
# |           ZMB.9_1|
# |        2.91075952|
# |        8.68623224|
# |2.3626830135665684|
# |0.6074737700000001|
# |0.5969723699999999|
# |0.5897305899999999|
# |0.6107070000000001|
# |0.6139374999999999|
# |        0.59750472|
# |        0.54703157|
# |           EGY.3_1|
# |          THA.13_1|
# |           BTN.1_1|
# +------------------+
# only showing top 20 rows
#
# Other1 Count:
# 15184500
# Other1 Value Counts:
# +------------------+-----+
# |            other1|count|
# +------------------+-----+
# |          AFG.28_1| 2028|
# |          RUS.26_1| 4956|
# |          TUR.56_1| 3456|
# |          DOM.24_1| 1800|
# |          DZA.45_1| 5160|
# |           ESP.4_1| 1212|
# |           ZMB.9_1| 2844|
# |        2.91075952|    7|
# |        8.68623224|    4|
# |2.3626830135665684|   10|
# |0.6074737700000001|   28|
# |0.5969723699999999|    1|
# |0.5897305899999999|    5|
# |0.6107070000000001|    2|
# |0.6139374999999999|    1|
# |        0.59750472|    8|
# |        0.54703157|    1|
# |           EGY.3_1| 3660|
# |          THA.13_1| 1824|
# |           BTN.1_1|  912|
# +------------------+-----+
# only showing top 20 rows
#
# Other1 Null Count:
# 2103121
# other2
# ================================================================
#
# Other2 Data Type
# StringType()
# Other2 Head Values:
# +---------+
# |   other2|
# +---------+
# |KGZ.4.2_1|
# |KGZ.4.2_1|
# |KGZ.4.2_1|
# |KGZ.4.2_1|
# |KGZ.7.1_1|
# +---------+
# only showing top 5 rows
#
# Other2 Tail Values:
# +--------------------+
# |              other2|
# +--------------------+
# |warm_temperate_moist|
# |warm_temperate_moist|
# |warm_temperate_moist|
# |warm_temperate_moist|
# |warm_temperate_moist|
# +--------------------+
# only showing top 5 rows
#
# Other2 Distinct Values:
# +------------+
# |      other2|
# +------------+
# |   LUX.3.1_1|
# | MEX.13.43_2|
# |MEX.20.567_2|
# |   ALB.6.3_1|
# | ARG.18.12_1|
# |  BGR.27.1_1|
# |  BRA.13.4_2|
# | BRA.5.101_2|
# | BRA.5.106_2|
# | BRA.9.102_2|
# | BRA.9.156_2|
# |  ROU.2.60_1|
# |  RUS.15.1_1|
# | SLV.11.10_1|
# |   TCD.4.2_1|
# |   TLS.4.1_1|
# | BRA.5.409_2|
# |  CAN.2.22_1|
# | COL.11.38_2|
# |  GTM.19.1_1|
# +------------+
# only showing top 20 rows
#
# Other2 Count:
# 15184500
# Other2 Value Counts:
# +------------+-----+
# |      other2|count|
# +------------+-----+
# |   LUX.3.1_1|  204|
# | MEX.13.43_2|  192|
# |MEX.20.567_2|  168|
# |   ALB.6.3_1|  204|
# | ARG.18.12_1|  180|
# |  BGR.27.1_1|  204|
# |  BRA.13.4_2|  204|
# | BRA.5.101_2|  204|
# | BRA.5.106_2|  204|
# | BRA.9.102_2|  192|
# | BRA.9.156_2|  204|
# |  ROU.2.60_1|  204|
# |  RUS.15.1_1|  204|
# | SLV.11.10_1|  204|
# |   TCD.4.2_1|  192|
# |   TLS.4.1_1|  192|
# | BRA.5.409_2|  204|
# |  CAN.2.22_1|  204|
# | COL.11.38_2|  204|
# |  GTM.19.1_1|  204|
# +------------+-----+
# only showing top 20 rows
#
# Other2 Null Count:
# 2793828
# other3
# ================================================================
#
# Other3 Data Type
# StringType()
# Other3 Head Values:
# +------+
# |other3|
# +------+
# |     2|
# |     2|
# |     2|
# |     2|
# |     2|
# +------+
# only showing top 5 rows
#
# Other3 Tail Values:
# +-----------------------------+
# |                       other3|
# +-----------------------------+
# |麻山路, 云桥社区, 彭家, Ji...|
# |麻山路, 云桥社区, 彭家, Ji...|
# |麻山路, 云桥社区, 彭家, Ji...|
# |麻山路, 云桥社区, 彭家, Ji...|
# |麻山路, 云桥社区, 彭家, Ji...|
# +-----------------------------+
# only showing top 5 rows
#
# Other3 Distinct Values:
# +---------------+
# |         other3|
# +---------------+
# |          36.65|
# |          151.0|
# |         1763.0|
# |           7.16|
# |          102.0|
# |          247.0|
# |  Nickel/Cobalt|
# |  4712.59004203|
# |  2684.93184702|
# |   160.78164885|
# |  1075.58748749|
# | 53392.47856553|
# |117152.48083023|
# |  7169.34294815|
# |  11021.5911589|
# |  2460.29473394|
# |  3069.83816635|
# |  1464.16318746|
# |  1764.06677558|
# |  3126.72778345|
# +---------------+
# only showing top 20 rows
#
# Other3 Count:
# 15184500
# Other3 Value Counts:
# +---------------+-----+
# |         other3|count|
# +---------------+-----+
# |          36.65|   12|
# |          151.0|   48|
# |         1763.0|   12|
# |           7.16|   12|
# |          102.0|   12|
# |          247.0|   12|
# |  Nickel/Cobalt|   72|
# |  4712.59004203|   10|
# |  2684.93184702|   20|
# |   160.78164885|    5|
# |  1075.58748749|    5|
# | 53392.47856553|    1|
# |117152.48083023|    1|
# |  7169.34294815|    1|
# |  11021.5911589|    1|
# |  2460.29473394|    1|
# |  3069.83816635|    2|
# |  1464.16318746|    1|
# |  1764.06677558|    1|
# |  3126.72778345|    1|
# +---------------+-----+
# only showing top 20 rows
#
# Other3 Null Count:
# 946296
# other4
# ================================================================
#
# Other4 Data Type
# StringType()
# Other4 Head Values:
# +------+
# |other4|
# +------+
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# +------+
# only showing top 5 rows
#
# Other4 Tail Values:
# +--------+
# |  other4|
# +--------+
# |reported|
# |reported|
# |reported|
# |reported|
# |reported|
# +--------+
# only showing top 5 rows
#
# Other4 Distinct Values:
# +------------------+
# |            other4|
# +------------------+
# |238034.08145766347|
# |  3977.93896642496|
# | 3441.344106229489|
# | 341168.4062260221|
# | 872222.2295297598|
# | 600286.2775402828|
# |175900.97799511004|
# | 68.82688212458979|
# | 722.5832782974671|
# |305967.73281326186|
# | 92233.75134080937|
# |2407.0408071428574|
# |       25545.40632|
# | 8947.833898500001|
# |    43476.13913776|
# | 21352.16243840001|
# | 27829.68910337857|
# | 36127.59844575001|
# |44864.110860750014|
# |47312.842942375006|
# +------------------+
# only showing top 20 rows
#
# Other4 Count:
# 15184500
# Other4 Value Counts:
# +------------------+-----+
# |            other4|count|
# +------------------+-----+
# |238034.08145766347|    1|
# |  3977.93896642496|    1|
# | 3441.344106229489|    2|
# | 341168.4062260221|    4|
# | 872222.2295297598|    1|
# | 600286.2775402828|    1|
# |175900.97799511004|    1|
# | 68.82688212458979|    1|
# | 722.5832782974671|    1|
# |305967.73281326186|    1|
# | 92233.75134080937|    1|
# |2407.0408071428574|    1|
# |       25545.40632|    1|
# | 8947.833898500001|    1|
# |    43476.13913776|    1|
# | 21352.16243840001|    1|
# | 27829.68910337857|    1|
# | 36127.59844575001|    1|
# |44864.110860750014|    2|
# |47312.842942375006|    1|
# +------------------+-----+
# only showing top 20 rows
#
# Other4 Null Count:
# 12668220
# other5
# ================================================================
#
# Other5 Data Type
# StringType()
# Other5 Head Values:
# +------+
# |other5|
# +------+
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# +------+
# only showing top 5 rows
#
# Other5 Tail Values:
# +----------------------------------------+
# |                                  other5|
# +----------------------------------------+
# |内蒙古太西煤集团金昌鑫华焦化有限责任公司|
# |内蒙古太西煤集团金昌鑫华焦化有限责任公司|
# |内蒙古太西煤集团金昌鑫华焦化有限责任公司|
# |内蒙古太西煤集团金昌鑫华焦化有限责任公司|
# |内蒙古太西煤集团金昌鑫华焦化有限责任公司|
# +----------------------------------------+
# only showing top 5 rows
#
# Other5 Distinct Values:
# +------------------+
# |            other5|
# +------------------+
# |           0.02572|
# |           0.07692|
# |0.1688899999999999|
# |           0.07249|
# |           0.74342|
# |             0.273|
# |             0.157|
# |             0.871|
# |             0.216|
# |             0.151|
# |             0.899|
# |             0.962|
# |           0.21614|
# |           0.70554|
# |              0.55|
# |             0.671|
# |             0.762|
# |               1.0|
# |             0.147|
# |             0.937|
# +------------------+
# only showing top 20 rows
#
# Other5 Count:
# 15184500
# Other5 Value Counts:
# +------------------+------+
# |            other5| count|
# +------------------+------+
# |           0.02572|     8|
# |           0.07692|     2|
# |0.1688899999999999|     1|
# |           0.07249|    17|
# |           0.74342|    49|
# |             0.273|   104|
# |             0.157|    30|
# |             0.871|    54|
# |             0.216|    81|
# |             0.151|    39|
# |             0.899|     3|
# |             0.962|     1|
# |           0.21614|     2|
# |           0.70554|     5|
# |              0.55|  6804|
# |             0.671|    14|
# |             0.762|     7|
# |               1.0|457859|
# |             0.147|    12|
# |             0.937|    11|
# +------------------+------+
# only showing top 20 rows
#
# Other5 Null Count:
# 12323568
# other6
# ================================================================
#
# Other6 Data Type
# StringType()
# Other6 Head Values:
# +------+
# |other6|
# +------+
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# +------+
# only showing top 5 rows
#
# Other6 Tail Values:
# +--------+
# |  other6|
# +--------+
# |锦阳电厂|
# |锦阳电厂|
# |锦阳电厂|
# |锦阳电厂|
# |锦阳电厂|
# +--------+
# only showing top 5 rows
#
# Other6 Distinct Values:
# +------------------+
# |            other6|
# +------------------+
# | 10230.76923076923|
# |      4003.4671875|
# |16745.230769230773|
# |16469.600000000002|
# |14897.458934285716|
# |13486.946052000005|
# |10708.624285714286|
# |  8664.45882352941|
# |21248.580341357145|
# |        6772.12031|
# | 18608.72365685821|
# |16957.027857288336|
# |    1053.389467125|
# |2455.7226525036453|
# |       8522.299244|
# | 24690.49166666667|
# |12091.218750000002|
# |     33131.2260956|
# |12255.780882352945|
# | 10925.32644923077|
# +------------------+
# only showing top 20 rows
#
# Other6 Count:
# 15184500
# Other6 Value Counts:
# +------------------+-----+
# |            other6|count|
# +------------------+-----+
# | 10230.76923076923|    2|
# |      4003.4671875|    1|
# |16745.230769230773|    1|
# |16469.600000000002|    2|
# |14897.458934285716|    2|
# |13486.946052000005|    1|
# |10708.624285714286|    1|
# |  8664.45882352941|    1|
# |21248.580341357145|    1|
# |        6772.12031|    2|
# | 18608.72365685821|    1|
# |16957.027857288336|    1|
# |    1053.389467125|    1|
# |2455.7226525036453|    1|
# |       8522.299244|    1|
# | 24690.49166666667|    1|
# |12091.218750000002|    1|
# |     33131.2260956|    1|
# |12255.780882352945|    1|
# | 10925.32644923077|    1|
# +------------------+-----+
# only showing top 20 rows
#
# Other6 Null Count:
# 12433560
# other7
# ================================================================
#
# Other7 Data Type
# StringType()
# Other7 Head Values:
# +------+
# |other7|
# +------+
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# +------+
# only showing top 5 rows
#
# Other7 Tail Values:
# +------+
# |other7|
# +------+
# |     Y|
# |     Y|
# |     Y|
# |     Y|
# |     Y|
# +------+
# only showing top 5 rows
#
# Other7 Distinct Values:
# +-----------------+
# |           other7|
# +-----------------+
# |            151.0|
# |            373.0|
# |0.557734833233333|
# |0.448932825722222|
# |0.408950377666667|
# |0.634349224888889|
# |            360.0|
# |           684.93|
# |0.542553340666667|
# |0.406545164764815|
# |0.832261656888889|
# |0.724723214027778|
# |0.572686989522222|
# |            353.0|
# |0.455166804225185|
# |0.652439559055556|
# |0.469761884166667|
# |0.401233826666667|
# |            144.9|
# |            705.0|
# +-----------------+
# only showing top 20 rows
#
# Other7 Count:
# 15184500
# Other7 Value Counts:
# +-----------------+-----+
# |           other7|count|
# +-----------------+-----+
# |            151.0|   12|
# |            373.0| 2136|
# |0.557734833233333|   11|
# |0.448932825722222|    1|
# |0.408950377666667|    1|
# |0.634349224888889|    2|
# |            360.0|   48|
# |           684.93|   12|
# |0.542553340666667|    4|
# |0.406545164764815|    1|
# |0.832261656888889|    3|
# |0.724723214027778|   32|
# |0.572686989522222|   24|
# |            353.0|   12|
# |0.455166804225185|    2|
# |0.652439559055556|    1|
# |0.469761884166667|    2|
# |0.401233826666667|    1|
# |            144.9|   12|
# |            705.0|   12|
# +-----------------+-----+
# only showing top 20 rows
#
# Other7 Null Count:
# 12479217
# other8
# ================================================================
#
# Other8 Data Type
# StringType()
# Other8 Head Values:
# +------+
# |other8|
# +------+
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# +------+
# only showing top 5 rows
#
# Other8 Tail Values:
# +----------+
# |    other8|
# +----------+
# |Sand cover|
# |Sand cover|
# |Sand cover|
# |Sand cover|
# |Sand cover|
# +----------+
# only showing top 5 rows
#
# Other8 Distinct Values:
# +------------------+
# |            other8|
# +------------------+
# |             102.0|
# |             247.0|
# |             151.0|
# |     2694.03736875|
# |12037.772337863998|
# |  43200.4394390205|
# |  5457.25759090909|
# |   12728.796388165|
# |         290.71875|
# |      93163.809375|
# | 523.8449999999999|
# |5292.4173157800005|
# | 5604.054478465625|
# |      113.85299415|
# |       593.3256875|
# |2330.4455916313605|
# |       562.0489875|
# |15540.155570939996|
# |      1941.7057296|
# |     3288.97098075|
# +------------------+
# only showing top 20 rows
#
# Other8 Count:
# 15184500
# Other8 Value Counts:
# +------------------+-----+
# |            other8|count|
# +------------------+-----+
# |             102.0| 2556|
# |             247.0| 1320|
# |             151.0| 1344|
# |     2694.03736875|    1|
# |12037.772337863998|    1|
# |  43200.4394390205|    1|
# |  5457.25759090909|    1|
# |   12728.796388165|    1|
# |         290.71875|    1|
# |      93163.809375|    1|
# | 523.8449999999999|    1|
# |5292.4173157800005|    2|
# | 5604.054478465625|    1|
# |      113.85299415|    1|
# |       593.3256875|    1|
# |2330.4455916313605|    1|
# |       562.0489875|    1|
# |15540.155570939996|    1|
# |      1941.7057296|    1|
# |     3288.97098075|    1|
# +------------------+-----+
# only showing top 20 rows
#
# Other8 Null Count:
# 12966768
# other9
# ================================================================
#
# Other9 Data Type
# StringType()
# Other9 Head Values:
# +------+
# |other9|
# +------+
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# |  NULL|
# +------+
# only showing top 5 rows
#
# Other9 Tail Values:
# +----------------+
# |          other9|
# +----------------+
# |99994.5927734375|
# |99994.5927734375|
# |99994.5927734375|
# |99994.5927734375|
# |99994.5927734375|
# +----------------+
# only showing top 5 rows
#
# Other9 Distinct Values:
# +------------------+
# |            other9|
# +------------------+
# |  72863.1646834612|
# |  486579.179449815|
# |  262856.469402015|
# |  60973.4017181396|
# |           0.74342|
# |           0.02572|
# |           0.07692|
# |           0.07249|
# |0.1688899999999999|
# |  155972.857736476|
# |  81972.1928901672|
# |  64760.3378257751|
# |  107438.474609375|
# |  118683.547752701|
# |  235097.708782196|
# |  907798.120566845|
# |  126632.047470093|
# |  119075.766144693|
# |  144501.908026695|
# |  336183.146208286|
# +------------------+
# only showing top 20 rows
#
# Other9 Count:
# 15184500
# Other9 Value Counts:
# +------------------+-----+
# |            other9|count|
# +------------------+-----+
# |  72863.1646834612|  180|
# |  486579.179449815|  168|
# |  262856.469402015|  108|
# |  60973.4017181396|   96|
# |           0.74342|  150|
# |           0.02572|    1|
# |           0.07692|    1|
# |           0.07249|   27|
# |0.1688899999999999|    4|
# |  155972.857736476|  132|
# |  81972.1928901672|  108|
# |  64760.3378257751|  144|
# |  107438.474609375|  120|
# |  118683.547752701|  156|
# |  235097.708782196|  156|
# |  907798.120566845|  180|
# |  126632.047470093|  132|
# |  119075.766144693|  168|
# |  144501.908026695|  120|
# |  336183.146208286|  120|
# +------------------+-----+
# only showing top 20 rows
#
# Other9 Null Count:
# 12958872
# other10
# ================================================================
#
# Other10 Data Type
# StringType()
# Other10 Head Values:
# +-------+
# |other10|
# +-------+
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# +-------+
# only showing top 5 rows
#
# Other10 Tail Values:
# +---------+
# |  other10|
# +---------+
# |satellite|
# |satellite|
# |satellite|
# |satellite|
# |satellite|
# +---------+
# only showing top 5 rows
#
# Other10 Distinct Values:
# +--------------------+
# |             other10|
# +--------------------+
# |[{'aerobic_treatm...|
# |[{'aerobic_treatm...|
# |[{'liquid_slurry'...|
# |[{'liquid_slurry'...|
# |[{'liquid_slurry'...|
# |[{'aerobic_treatm...|
# |[{'aerobic_treatm...|
# |[{'liquid_slurry'...|
# |[{'liquid_slurry'...|
# |       [{'pond': 1}]|
# |    [{'compost': 1}]|
# |[{'aerobic_treatm...|
# |[{'liquid_slurry'...|
# |[{'aerobic_treatm...|
# |[{'aerobic_treatm...|
# |[{'liquid_slurry'...|
# |[{'aerobic_treatm...|
# |[{'liquid_slurry'...|
# |[{'aerobic_treatm...|
# |[{'aerobic_treatm...|
# +--------------------+
# only showing top 20 rows
#
# Other10 Count:
# 15184500
# Other10 Value Counts:
# +--------------------+-----+
# |             other10|count|
# +--------------------+-----+
# |[{'aerobic_treatm...|   24|
# |[{'aerobic_treatm...|  216|
# |[{'liquid_slurry'...|  168|
# |[{'liquid_slurry'...|   12|
# |[{'liquid_slurry'...|   84|
# |[{'aerobic_treatm...|   36|
# |[{'aerobic_treatm...|   12|
# |[{'liquid_slurry'...|   12|
# |[{'liquid_slurry'...|  840|
# |       [{'pond': 1}]|17424|
# |    [{'compost': 1}]|   12|
# |[{'aerobic_treatm...|   24|
# |[{'liquid_slurry'...|   24|
# |[{'aerobic_treatm...|   36|
# |[{'aerobic_treatm...|  120|
# |[{'liquid_slurry'...|   24|
# |[{'aerobic_treatm...|   12|
# |[{'liquid_slurry'...|  180|
# |[{'aerobic_treatm...|   36|
# |[{'aerobic_treatm...|   12|
# +--------------------+-----+
# only showing top 20 rows
#
# Other10 Null Count:
# 14263500
# other11
# ================================================================
#
# Other11 Data Type
# StringType()
# Other11 Head Values:
# +-------+
# |other11|
# +-------+
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# +-------+
# only showing top 5 rows
#
# Other11 Tail Values:
# +-------+
# |other11|
# +-------+
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# +-------+
# only showing top 5 rows
#
# Other11 Distinct Values:
# +-------+
# |other11|
# +-------+
# |   NULL|
# +-------+
#
# Other11 Count:
# 15184500
# Other11 Value Counts:
# +-------+--------+
# |other11|   count|
# +-------+--------+
# |   NULL|15184500|
# +-------+--------+
#
# Other11 Null Count:
# 15184500
# other12
# ================================================================
#
# Other12 Data Type
# StringType()
# Other12 Head Values:
# +-------+
# |other12|
# +-------+
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# +-------+
# only showing top 5 rows
#
# Other12 Tail Values:
# +-------+
# |other12|
# +-------+
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# |   NULL|
# +-------+
# only showing top 5 rows
#
# Other12 Distinct Values:
# +-------+
# |other12|
# +-------+
# |   NULL|
# +-------+
#
# Other12 Count:
# 15184500
# Other12 Value Counts:
# +-------+--------+
# |other12|   count|
# +-------+--------+
# |   NULL|15184500|
# +-------+--------+
#
# Other12 Null Count:
# 15184500

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">confidence metrics</span>
# Level of data accuracy measured in confidence
#
# Data Type: `string`
#
# **Status: <span style="color: read;">NOT READY</span>**
#
# Problems:
# 1. The values are nearly uniform for each dataset. These values can be added as metadata in the documentation to reduce overhead due to redundancy

# %%
# Data Confidence Exploration
metric_fields = {
    "conf_source_type": "Source Type Confidence Level",
    "conf_capacity": "Capacity Confidence Level",
    "conf_capacity_factor": "Capacity Factor Confidence Level",
    "conf_activity": "Activity Confidence Level",
    "conf_emissions_factor": "Emissions Factor Confidence Level",
    "conf_emissions_quantity" : "Emissions Quantity Confidence Level"
}

for each in metric_fields:
    column_title = metric_fields[each]
    column_name = each

    print(f"""{column_name}
================================================================
""")

    print(f"{column_title} Data Type")
    data_type = df.schema[column_name].dataType
    print(data_type)

    print(f"{column_title} Head Values:")
    df.select(column_name).show(5)

    print(f"{column_title} Tail Values:")
    df.select(column_name).orderBy(column_name, ascending=False).show(5)

    if isinstance(data_type, StringType):
        print(f"{column_title} Distinct Values:")
        df.select(column_name).distinct().show()

        print(f"{column_title} Distinct Count:")
        print(df.select(column_name).distinct().count())

    print(f"{column_title} Count:")
    print(df.count())

    print(f"{column_title} Value Counts:")
    df.groupBy(column_name).count().show()

    print(f"{column_title} Null Count:")
    print(df.filter(col(column_name).isNull()).count())
# Out:
# conf_source_type
# ================================================================
#
# Source Type Confidence Level Data Type
# StringType()
# Source Type Confidence Level Head Values:
# +----------------+
# |conf_source_type|
# +----------------+
# |        very low|
# |        very low|
# |        very low|
# |        very low|
# |        very low|
# +----------------+
# only showing top 5 rows
#
# Source Type Confidence Level Tail Values:
# +----------------+
# |conf_source_type|
# +----------------+
# |        very low|
# |        very low|
# |        very low|
# |        very low|
# |        very low|
# +----------------+
# only showing top 5 rows
#
# Source Type Confidence Level Distinct Values:
# +----------------+
# |conf_source_type|
# +----------------+
# |             low|
# |        very low|
# |            high|
# |          medium|
# |       very high|
# +----------------+
#
# Source Type Confidence Level Count:
# 15184500
# Source Type Confidence Level Value Counts:
# +----------------+--------+
# |conf_source_type|   count|
# +----------------+--------+
# |             low|  122064|
# |        very low|13857291|
# |            high|  511485|
# |          medium|  529764|
# |       very high|  163896|
# +----------------+--------+
#
# Source Type Confidence Level Null Count:
# 0
# conf_capacity
# ================================================================
#
# Capacity Confidence Level Data Type
# StringType()
# Capacity Confidence Level Head Values:
# +-------------+
# |conf_capacity|
# +-------------+
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# +-------------+
# only showing top 5 rows
#
# Capacity Confidence Level Tail Values:
# +-------------+
# |conf_capacity|
# +-------------+
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# +-------------+
# only showing top 5 rows
#
# Capacity Confidence Level Distinct Values:
# +-------------+
# |conf_capacity|
# +-------------+
# |          low|
# |     very low|
# |         high|
# |       medium|
# |    very high|
# +-------------+
#
# Capacity Confidence Level Count:
# 15184500
# Capacity Confidence Level Value Counts:
# +-------------+-------+
# |conf_capacity|  count|
# +-------------+-------+
# |          low|2768261|
# |     very low|9490780|
# |         high|1292271|
# |       medium| 546108|
# |    very high|1087080|
# +-------------+-------+
#
# Capacity Confidence Level Null Count:
# 0
# conf_capacity_factor
# ================================================================
#
# Capacity Factor Confidence Level Data Type
# StringType()
# Capacity Factor Confidence Level Head Values:
# +--------------------+
# |conf_capacity_factor|
# +--------------------+
# |            very low|
# |            very low|
# |            very low|
# |            very low|
# |            very low|
# +--------------------+
# only showing top 5 rows
#
# Capacity Factor Confidence Level Tail Values:
# +--------------------+
# |conf_capacity_factor|
# +--------------------+
# |            very low|
# |            very low|
# |            very low|
# |            very low|
# |            very low|
# +--------------------+
# only showing top 5 rows
#
# Capacity Factor Confidence Level Distinct Values:
# +--------------------+
# |conf_capacity_factor|
# +--------------------+
# |                 low|
# |            very low|
# |                high|
# |              medium|
# |           very high|
# +--------------------+
#
# Capacity Factor Confidence Level Count:
# 15184500
# Capacity Factor Confidence Level Value Counts:
# +--------------------+-------+
# |conf_capacity_factor|  count|
# +--------------------+-------+
# |                 low|1317912|
# |            very low|9711190|
# |                high|1060361|
# |              medium|2419569|
# |           very high| 675468|
# +--------------------+-------+
#
# Capacity Factor Confidence Level Null Count:
# 0
# conf_activity
# ================================================================
#
# Activity Confidence Level Data Type
# StringType()
# Activity Confidence Level Head Values:
# +-------------+
# |conf_activity|
# +-------------+
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# +-------------+
# only showing top 5 rows
#
# Activity Confidence Level Tail Values:
# +-------------+
# |conf_activity|
# +-------------+
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# |     very low|
# +-------------+
# only showing top 5 rows
#
# Activity Confidence Level Distinct Values:
# +-------------+
# |conf_activity|
# +-------------+
# |          low|
# |     very low|
# |         high|
# |       medium|
# |    very high|
# +-------------+
#
# Activity Confidence Level Count:
# 15184500
# Activity Confidence Level Value Counts:
# +-------------+-------+
# |conf_activity|  count|
# +-------------+-------+
# |          low|1863254|
# |     very low|9620560|
# |         high|1087739|
# |       medium|2595475|
# |    very high|  17472|
# +-------------+-------+
#
# Activity Confidence Level Null Count:
# 0
# conf_emissions_factor
# ================================================================
#
# Emissions Factor Confidence Level Data Type
# StringType()
# Emissions Factor Confidence Level Head Values:
# +---------------------+
# |conf_emissions_factor|
# +---------------------+
# |             very low|
# |             very low|
# |             very low|
# |             very low|
# |             very low|
# +---------------------+
# only showing top 5 rows
#
# Emissions Factor Confidence Level Tail Values:
# +---------------------+
# |conf_emissions_factor|
# +---------------------+
# |             very low|
# |             very low|
# |             very low|
# |             very low|
# |             very low|
# +---------------------+
# only showing top 5 rows
#
# Emissions Factor Confidence Level Distinct Values:
# +---------------------+
# |conf_emissions_factor|
# +---------------------+
# |                  low|
# |             very low|
# |               medium|
# |            very high|
# |                 high|
# +---------------------+
#
# Emissions Factor Confidence Level Count:
# 15184500
# Emissions Factor Confidence Level Value Counts:
# +---------------------+-------+
# |conf_emissions_factor|  count|
# +---------------------+-------+
# |                  low|2266314|
# |             very low|6536583|
# |               medium| 449772|
# |            very high|5891403|
# |                 high|  40428|
# +---------------------+-------+
#
# Emissions Factor Confidence Level Null Count:
# 0
# conf_emissions_quantity
# ================================================================
#
# Emissions Quantity Confidence Level Data Type
# StringType()
# Emissions Quantity Confidence Level Head Values:
# +-----------------------+
# |conf_emissions_quantity|
# +-----------------------+
# |               very low|
# |               very low|
# |               very low|
# |               very low|
# |               very low|
# +-----------------------+
# only showing top 5 rows
#
# Emissions Quantity Confidence Level Tail Values:
# +-----------------------+
# |conf_emissions_quantity|
# +-----------------------+
# |               very low|
# |               very low|
# |               very low|
# |               very low|
# |               very low|
# +-----------------------+
# only showing top 5 rows
#
# Emissions Quantity Confidence Level Distinct Values:
# +-----------------------+
# |conf_emissions_quantity|
# +-----------------------+
# |                    low|
# |               very low|
# |                   high|
# |                 medium|
# |              very high|
# +-----------------------+
#
# Emissions Quantity Confidence Level Count:
# 15184500
# Emissions Quantity Confidence Level Value Counts:
# +-----------------------+-------+
# |conf_emissions_quantity|  count|
# +-----------------------+-------+
# |                    low|2302422|
# |               very low|6563475|
# |                   high|5668392|
# |                 medium| 515784|
# |              very high| 134427|
# +-----------------------+-------+
#
# Emissions Quantity Confidence Level Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">dates</span>
# Level of data accuracy measured in confidence
#
# Year Data Type: `long`
# Modified and Created Date Data Type: `timestamp`
#
# **Status: <span style="color: read;">READY</span>**

# %%
# Data Confidence Exploration
metric_fields = {
    "created_date": "Created Date",
    "modified_date": "Modified Date",
    "year": "Year"
}

for each in metric_fields:
    column_title = metric_fields[each]
    column_name = each

    print(f"""{column_name}
================================================================
""")

    print(f"{column_title} Data Type")
    data_type = df.schema[column_name].dataType
    print(data_type)

    print(f"{column_title} Head Values:")
    df.select(column_name).show(5)

    print(f"{column_title} Tail Values:")
    df.select(column_name).orderBy(column_name, ascending=False).show(5)

    if isinstance(data_type, StringType):
        print(f"{column_title} Distinct Values:")
        df.select(column_name).distinct().show()

        print(f"{column_title} Distinct Count:")
        print(df.select(column_name).distinct().count())

    print(f"{column_title} Count:")
    print(df.count())

    print(f"{column_title} Value Counts:")
    df.groupBy(column_name).count().show()

    print(f"{column_title} Null Count:")
    print(df.filter(col(column_name).isNull()).count())
# Out:
# created_date
# ================================================================
#
# Created Date Data Type
# TimestampType()
# Created Date Head Values:
# +-------------------+
# |       created_date|
# +-------------------+
# |2023-10-06 00:00:00|
# |2023-10-06 00:00:00|
# |2023-10-06 00:00:00|
# |2023-10-06 00:00:00|
# |2023-10-06 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# Created Date Tail Values:
# +-------------------+
# |       created_date|
# +-------------------+
# |2024-10-18 00:00:00|
# |2024-10-18 00:00:00|
# |2024-10-18 00:00:00|
# |2024-10-18 00:00:00|
# |2024-10-18 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# Created Date Count:
# 15184500
# Created Date Value Counts:
# +-------------------+-------+
# |       created_date|  count|
# +-------------------+-------+
# |2024-09-27 00:00:00|  13769|
# |2024-06-28 00:00:00|  11112|
# |2024-10-01 00:00:00| 121332|
# |2024-01-11 00:00:00|1084536|
# |2023-10-23 00:00:00|    168|
# |2024-10-12 00:00:00| 791412|
# |2023-09-15 00:00:00| 116472|
# |2024-09-26 00:00:00|   1632|
# |2024-07-26 00:00:00|    799|
# |2024-06-26 00:00:00|   4493|
# |2024-10-04 00:00:00|   4044|
# |2024-04-03 00:00:00|  92822|
# |2024-10-15 00:00:00| 615520|
# |2024-10-11 00:00:00| 298488|
# |2023-11-01 00:00:00|    336|
# |2024-09-17 00:00:00|1171656|
# |2024-09-18 00:00:00| 676188|
# |2024-08-22 00:00:00|    564|
# |2023-10-18 00:00:00|1098480|
# |2024-08-02 00:00:00| 866820|
# +-------------------+-------+
# only showing top 20 rows
#
# Created Date Null Count:
# 0
# modified_date
# ================================================================
#
# Modified Date Data Type
# TimestampType()
# Modified Date Head Values:
# +-------------+
# |modified_date|
# +-------------+
# |         NULL|
# |         NULL|
# |         NULL|
# |         NULL|
# |         NULL|
# +-------------+
# only showing top 5 rows
#
# Modified Date Tail Values:
# +-------------+
# |modified_date|
# +-------------+
# |         NULL|
# |         NULL|
# |         NULL|
# |         NULL|
# |         NULL|
# +-------------+
# only showing top 5 rows
#
# Modified Date Count:
# 15184500
# Modified Date Value Counts:
# +-------------+--------+
# |modified_date|   count|
# +-------------+--------+
# |         NULL|15184500|
# +-------------+--------+
#
# Modified Date Null Count:
# 15184500
# year
# ================================================================
#
# Year Data Type
# LongType()
# Year Head Values:
# +----+
# |year|
# +----+
# |2021|
# |2021|
# |2021|
# |2021|
# |2021|
# +----+
# only showing top 5 rows
#
# Year Tail Values:
# +----+
# |year|
# +----+
# |2021|
# |2021|
# |2021|
# |2021|
# |2021|
# +----+
# only showing top 5 rows
#
# Year Count:
# 15184500
# Year Value Counts:
# +----+--------+
# |year|   count|
# +----+--------+
# |2021|15184500|
# +----+--------+
#
# Year Null Count:
# 0

# %% [markdown]
# ### <span style="color: white; font-weight: bold; text-decoration: underline;">sources</span>
# Data sources
#
# Data Type: `string`
#
# **Status: <span style="color: read;">READY</span>**

# %%
# Sources Exploration
metric_fields = {
    "source_name": "Source Name",
    "source_type": "Source Type"
}

for each in metric_fields:
    column_title = metric_fields[each]
    column_name = each

    print(f"""{column_name}
================================================================
""")

    print(f"{column_title} Data Type")
    data_type = df.schema[column_name].dataType
    print(data_type)

    print(f"{column_title} Head Values:")
    df.select(column_name).show(5)

    print(f"{column_title} Tail Values:")
    df.select(column_name).orderBy(column_name, ascending=False).show(5)

    if isinstance(data_type, StringType):
        print(f"{column_title} Distinct Values:")
        df.select(column_name).distinct().show()

        print(f"{column_title} Distinct Count:")
        print(df.select(column_name).distinct().count())

    print(f"{column_title} Count:")
    print(df.count())

    print(f"{column_title} Value Counts:")
    df.groupBy(column_name).count().show()

    print(f"{column_title} Null Count:")
    print(df.filter(col(column_name).isNull()).count())
# Out:
# source_name
# ================================================================
#
# Source Name Data Type
# StringType()
# Source Name Head Values:
# +-----------+
# |source_name|
# +-----------+
# |   Ala-Buka|
# |   Ala-Buka|
# |   Ala-Buka|
# |   Ala-Buka|
# |       Alai|
# +-----------+
# only showing top 5 rows
#
# Source Name Tail Values:
# +-----------+
# |source_name|
# +-----------+
# |       웅상|
# |       웅상|
# |       웅상|
# |       웅상|
# |       웅상|
# +-----------+
# only showing top 5 rows
#
# Source Name Distinct Values:
# +--------------------+
# |         source_name|
# +--------------------+
# |            Vilniaus|
# |            Coapilla|
# |Santa Ana Ateixtl...|
# |        Villahermosa|
# |            Xicotlán|
# |           Bar Kunar|
# |           Bolyarovo|
# |        Borrazópolis|
# |              Pongaí|
# |    Agapovskiy rayon|
# |  Kardymovskiy rayon|
# |               Topki|
# |         Tejutepeque|
# |             Na Thom|
# |Le Haut-Saint-Fra...|
# |     Le Rocher-Percé|
# |            Donggang|
# |           Kisangani|
# |            Fredonia|
# |            Girardot|
# +--------------------+
# only showing top 20 rows
#
# Source Name Distinct Count:
# 244017
# Source Name Count:
# 15184500
# Source Name Value Counts:
# +--------------------+-----+
# |         source_name|count|
# +--------------------+-----+
# |            Vilniaus|  408|
# |            Coapilla|  204|
# |Santa Ana Ateixtl...|  192|
# |        Villahermosa|  408|
# |            Xicotlán|  192|
# |           Bar Kunar|  204|
# |           Bolyarovo|  204|
# |        Borrazópolis|  204|
# |              Pongaí|  204|
# |    Agapovskiy rayon|  204|
# |  Kardymovskiy rayon|  204|
# |               Topki|  204|
# |         Tejutepeque|  192|
# |             Na Thom|  204|
# |Le Haut-Saint-Fra...|  204|
# |     Le Rocher-Percé|  204|
# |            Donggang|  180|
# |           Kisangani|  348|
# |            Fredonia|  204|
# |            Girardot|  792|
# +--------------------+-----+
# only showing top 20 rows
#
# Source Name Null Count:
# 96768
# source_type
# ================================================================
#
# Source Type Data Type
# StringType()
# Source Type Head Values:
# +-----------+
# |source_type|
# +-----------+
# |       NULL|
# |       NULL|
# |       NULL|
# |       NULL|
# |       NULL|
# +-----------+
# only showing top 5 rows
#
# Source Type Tail Values:
# +---------------+
# |    source_type|
# +---------------+
# |zinc_production|
# |zinc_production|
# |zinc_production|
# |zinc_production|
# |zinc_production|
# +---------------+
# only showing top 5 rows
#
# Source Type Distinct Values:
# +--------------------+
# |         source_type|
# +--------------------+
# |      DRI-EAF,BF/BOF|
# |manufacturer | Li...|
# |Meat Processing| ...|
# |Certification - E...|
# |coal, other_fossi...|
# |Certification - E...|
# |       biomass, coal|
# |Imported Product|...|
# |Meat Processing| ...|
# |Identification - ...|
# |manufacturer | Li...|
# |manufacturer | Li...|
# |Certification - E...|
# |Identification - ...|
# |Certification - E...|
# |Meat Processing| ...|
# |Meat Processing| ...|
# |enteric_fermentat...|
# |Meat Processing| ...|
# |Meat Processing| ...|
# +--------------------+
# only showing top 20 rows
#
# Source Type Distinct Count:
# 1778
# Source Type Count:
# 15184500
# Source Type Value Counts:
# +--------------------+------+
# |         source_type| count|
# +--------------------+------+
# |      DRI-EAF,BF/BOF|    12|
# |manufacturer | Li...|    12|
# |Meat Processing| ...|    96|
# |Certification - E...|    24|
# |coal, other_fossi...|    24|
# |Certification - E...|    12|
# |       biomass, coal|   240|
# |Imported Product|...|    12|
# |Meat Processing| ...|    24|
# |Identification - ...|    12|
# |manufacturer | Li...|    60|
# |manufacturer | Li...|    12|
# |Certification - E...|    12|
# |Identification - ...|    12|
# |Certification - E...|   228|
# |Meat Processing| ...|    24|
# |Meat Processing| ...|    12|
# |enteric_fermentat...|420936|
# |Meat Processing| ...|    84|
# |Meat Processing| ...|    48|
# +--------------------+------+
# only showing top 20 rows
#
# Source Type Null Count:
# 11739708
